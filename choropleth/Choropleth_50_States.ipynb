# %%
import csv
from bs4 import BeautifulSoup

# Map colors
### GRAYSCALE
# colors = ["#ffffff", "#f0f0f0", "#d9d9d9", "#bdbdbd", "#969696", "#737373", "#525252", "#252525"]
# colors = ["#f7f7f7", "#d9d9d9", "#bdbdbd", "#969696", "#636363", "#252525"]
# colors = ["#f7f7f7", "#cccccc", "#969696", "#525252"]

### REDS
# colors = ["#FFF5F0", "#FEE0D2", "#FCBBA1", "#FC9272", "#FB6A4A", "#EF3B2C", "#CB181D", "#99000D"]
# colors = ["#fee5d9", "#fcbba1", "#fc9272", "#fb6a4a", "#de2d26", "#a50f15"]
# colors = ["#FEE5D9", "#FCAE91", "#FB6A4A", "#CB181D"]

### Y/OR/RED
# colors = ["#FFFFCC", "#FFEDA0", "#FED976", "#FEB24C", "#FD8D3C", "#FC4E2A", "#E31A1C", "#B10026"]
# colors = ["#FFFFB2", "#FED976", "#FEB24C", "#FD8D3C", "#F03B20", "#BD0026"]




# Read in the defect rates
defect_rate = {}
min_value = 100; max_value = 0
reader = csv.reader(open(r'd:\choropleth\data\states.csv'), delimiter=",")
firstline = True
for row in reader:
    try:
        if firstline:
            firstline = False
            continue
        else:
            state = row[0]
            rate = float( row[1].strip() )
            defect_rate[state] = rate
            if rate > max_value:
                max_value = rate
            if rate < min_value:
                min_value = rate
    except:
        pass


### Purple/Red color scheme. Replace line below with colors above to try others.
colors = ["#f1eef6", "#d4b9da", "#c994c7", "#df65b0", "#dd1c77", "#980043"]


# Load the SVG map
svg = open('d:\choropleth\Blank_US_Map.svg', 'r').read()
soup = BeautifulSoup(svg)
paths = soup.findAll('path')

# Change colors accordingly
path_style = 'font-size:12px;fill-rule:nonzero;stroke:#000000;stroke-opacity:1;stroke-width:0.1;stroke-miterlimit:4;stroke-dasharray:none;stroke-linecap:butt;marker-start:none;stroke-linejoin:bevel;fill:'
for p in paths:
    
    if p['id'] not in ["State_Lines", "separator"]:
        
        try:
            rate = defect_rate[p['id']]
        except:
            continue
            
        #idx = min(int(rate/2), 5)
        
        
        if rate >= 0.7:
            color_class = 5
        elif rate >= 0.5:
            color_class = 4
        elif rate >= 0.3:
            color_class = 3
        elif rate >= 0.1:
            color_class = 2
        elif rate >= 0.05:
            color_class = 1
        else:
            color_class = 0


        color = colors[color_class]
        p['style'] = path_style + color
        print(p['id'], rate, color)

outfile = open(r'd:\choropleth\outputs\map3.svg','w')
outfile.write(soup.prettify())
outfile.close()
# Out:
# HI 0.0 #f1eef6
# AK 0.0 #f1eef6
# FL 0.111 #c994c7
# NH 0.308 #df65b0
# VT 0.0 #f1eef6
# RI 3.361 #980043
# NY 0.586 #dd1c77
# PA 0.958 #980043
# NJ 1.674 #980043
# DE 0.0 #f1eef6
# MD 0.634 #dd1c77
# VA 0.426 #df65b0
# WV 0.0 #f1eef6
# OH 0.708 #980043
# IN 0.911 #980043
# IL 0.638 #dd1c77
# CT 0.468 #df65b0
# WI 0.22 #c994c7
# NC 0.153 #c994c7
# MA 1.083 #980043
# TN 0.122 #c994c7
# AR 0.0 #f1eef6
# MO 0.517 #dd1c77
# GA 0.059 #d4b9da
# SC 0.0 #f1eef6
# KY 0.0 #f1eef6
# AL 0.0 #f1eef6
# LA 0.0 #f1eef6
# MS 0.0 #f1eef6
# IA 0.0 #f1eef6
# MN 0.23 #c994c7
# OK 0.0 #f1eef6
# TX 0.022 #f1eef6
# NM 0.0 #f1eef6
# KS 0.296 #c994c7
# NE 0.0 #f1eef6
# SD 0.0 #f1eef6
# CO 0.0 #f1eef6
# ID 0.0 #f1eef6
# UT 0.0 #f1eef6
# AZ 0.0 #f1eef6
# NV 0.0 #f1eef6
# OR 0.303 #df65b0
# WA 0.18 #c994c7
# CA 0.031 #f1eef6
