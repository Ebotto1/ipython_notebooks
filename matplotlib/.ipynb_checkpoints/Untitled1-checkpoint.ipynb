# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, MonthLocator, WeekdayLocator, DayLocator, DateFormatter
import dateutil
from matplotlib.ticker import MultipleLocator
from datetime import datetime
from datetime import date

# Data metadata:
# CSV file where first column is string date in dd/mm/YYYY H:M:S format and second column is the bitcoin price in US dollars
# Pandas.read_csv has an awesome converters parameter that allows us to convert or modify a column's data on the fly!
# Therefore, we can read the first column as an actual Python datetime object instead of as a string.
# Because there is time info with the date, it causes the x-axis ticks to not correspond with the data.
# As a workaround, I stripped the time from the date values by invoking datetime.date()
bitcoin_data = pd.read_csv("http://blockchain.info/charts/market-price?showDataPoints=false&timespan=&show_header=true&daysAverageString=1&scale=0&format=csv&address=",
                 index_col=0, names=['price'], converters={0: lambda x: datetime.date(datetime.strptime(x, '%d/%m/%Y %H:%M:%S'))})

# %%
print(matplotlib.__version__)
# Out:
# 1.4.2

# %%
fig = plt.figure()

axes = fig.add_axes([0, 1.4, 1.5, 1])

# These are just time intervals we can use to format our X axis tick intervals
year   = YearLocator()
month  = MonthLocator(bymonth=range(1,13),  bymonthday=1, interval=1)
week   = WeekdayLocator(byweekday=dateutil.rrule.MO)  # Every MOnday or WeekdayLocator(byweekday=0) works too
day    = DayLocator(bymonthday=range(1,32), interval=1)

############# Let's get last 2 calendar months' worth of bitcoin prices ###########
# But first, we must account for situation where current month is January
today = datetime.today()
this_month = today.month
if this_month==1:
    last_year = today.year - 1   # if month is January, then year will be one less than current year
    last_month = 12              # if month is January, then previous month is Dec (12)
else:
    last_year = today.year       # Otherwise, last year is really same as current year and
    last_month = this_month - 1  # last month will equal current month minus 1

this_year = today.year

# Pandas' filtering by date ranges only work if the dates are of type datetime.datetime
# Unfortunately, the data parsed from the CSV file, was parsed as datetime.date
# So we will convert bitcoin_data.index to datetime.datetime:
bitcoin_data.index = pd.to_datetime(bitcoin_data.index)

# Now I will take advantage of Pandas partial string indexing described below to get just 2 months of data:
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#partial-string-indexing
last2months = bitcoin_data[str(last_month)+'-'+str(last_year):str(this_month)+'-'+str(this_year)]

# Get current price and also the current date, convert it to a datetime.date, then make a string from it in mm/dd/YYYY format
current_price = last2months[-1:].values[0][0]
last_date = last2months[-1:].index
current_date_unformatted = date(last_date.year[0], last_date.month[0], last_date.day[0])
current_date = datetime.strftime(current_date_unformatted, "%m/%d/%Y")

# Format the x-axis tick labels as mm-dd-YYYY format, turn on grid for major ticks
dayFmt = DateFormatter("%b-%d-%Y")
axes.xaxis.set_major_locator(day)  # Make x-axis tick interval to be daily interval size
axes.xaxis.set_major_formatter(dayFmt)
axes.xaxis.grid(which='major')

# Format the y-axis
y_major_ticks = MultipleLocator(20)
axes.yaxis.set_major_locator(y_major_ticks)
axes.yaxis.set_ticks_position('right')  # Not sure why 'both' don't work
axes.yaxis.set_label_position('right')
axes.yaxis.grid(which='major')

# Plot the data...
axes.plot_date(last2months.index, last2months.values, 'r')
axes.set_title("Current Value@"+current_date+": "+str(current_price), weight="bold", size=10)
# MATPLOTLIB does not have a good way of creating a title with 2 rows of text with different font sizes
# Below is a workaround(http://matplotlib.org/users/text_intro.html), sort of "hackish" and requires trial and error (x,y)
axes.text(.22,1.07, "Last 2 Calendar Months of Bitcoin Values in US$", transform=axes.transAxes,
             weight="bold", size=14)
axes.set_xlabel("Month - Day - Year")
axes.set_ylabel("US$")
plt.setp(axes.get_xticklabels(), rotation=-90, size=8)
plt.setp(axes.get_yticklabels(), size=9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-3-b61a62505633> in <module>()
#      59 axes.set_xlabel("Month - Day - Year")
#      60 axes.set_ylabel("US$")
# ---> 61 plt.setp(axes.get_xticklabels(), rotation=-90, size=8)
#      62 plt.setp(axes.get_yticklabels(), size=9)
#      63 plt.show()
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/axes/_base.py in get_xticklabels(self, minor, which)
#    2641         return cbook.silent_list('Text xticklabel',
#    2642                                  self.xaxis.get_ticklabels(minor=minor,
# -> 2643                                                            which=which))
#    2644
#    2645     @docstring.dedent_interpd
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1212         if minor:
#    1213             return self.get_minorticklabels()
# -> 1214         return self.get_majorticklabels()
#    1215
#    1216     def get_majorticklines(self):
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1166     def get_majorticklabels(self):
#    1167         'Return a list of Text instances for the major ticklabels'
# -> 1168         ticks = self.get_major_ticks()
#    1169         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1170         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1295         'get the tick instances; grow as necessary'
#    1296         if numticks is None:
# -> 1297             numticks = len(self.get_major_locator()())
#    1298         if len(self.majorTicks) < numticks:
#    1299             # update the new tick label properties from the old
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/dates.py in __call__(self)
#     664         # if no data have been set, this will tank with a ValueError
#     665         try:
# --> 666             dmin, dmax = self.viewlim_to_dt()
#     667         except ValueError:
#     668             return []
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#     625     def viewlim_to_dt(self):
#     626         vmin, vmax = self.axis.get_view_interval()
# --> 627         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#     628
#     629     def _get_unit(self):
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/dates.py in num2date(x, tz)
#     343         tz = _get_rc_timezone()
#     344     if not cbook.iterable(x):
# --> 345         return _from_ordinalf(x, tz)
#     346     else:
#     347         x = np.asarray(x)
#
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/matplotlib/dates.py in _from_ordinalf(x, tz)
#     223         tz = _get_rc_timezone()
#     224     ix = int(x)
# --> 225     dt = datetime.datetime.fromordinal(ix)
#     226     remainder = float(x) - ix
#     227     hour, remainder = divmod(24 * remainder, 1)
#
# OverflowError: Python int too large to convert to C long
# /home/pybokeh/miniconda3/envs/ipynb3/lib/python3.4/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: Python int too large to convert to C long
#   FormatterWarning,

# %%
fig = plt.figure()

axes = fig.add_axes([0, 1.4, 1.5, 1])

# These are just time intervals we can use to format our X axis tick intervals
year   = YearLocator()
month  = MonthLocator(bymonth=range(1,13),  bymonthday=1, interval=1)
week   = WeekdayLocator(byweekday=dateutil.rrule.MO)  # Every MOnday or WeekdayLocator(byweekday=0) works too
day    = DayLocator(bymonthday=range(1,32), interval=1)

############# Let's get last 2 calendar months' worth of bitcoin prices ###########
# But first, we must account for situation where current month is January
today = datetime.today()
this_month = today.month
if this_month==1:
    last_year = today.year - 1   # if month is January, then year will be one less than current year
    last_month = 12              # if month is January, then previous month is Dec (12)
else:
    last_year = today.year       # Otherwise, last year is really same as current year and
    last_month = this_month - 1  # last month will equal current month minus 1

this_year = today.year

# Pandas' filtering by date ranges only work if the dates are of type datetime.datetime
# Unfortunately, the data parsed from the CSV file, was parsed as datetime.date
# So we will convert bitcoin_data.index to datetime.datetime:
bitcoin_data.index = pd.to_datetime(bitcoin_data.index)

# Now I will take advantage of Pandas partial string indexing described below to get just 2 months of data:
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#partial-string-indexing
last2months = bitcoin_data[str(last_month)+'-'+str(last_year):str(this_month)+'-'+str(this_year)]
idx = [datetime.date(data) for data in last2months.index]

# Get current price and also the current date, convert it to a datetime.date, then make a string from it in mm/dd/YYYY format
current_price = last2months[-1:].values[0][0]
last_date = last2months[-1:].index
current_date_unformatted = date(last_date.year[0], last_date.month[0], last_date.day[0])
current_date = datetime.strftime(current_date_unformatted, "%m/%d/%Y")

# Format the x-axis tick labels as mm-dd-YYYY format, turn on grid for major ticks
dayFmt = DateFormatter("%b-%d-%Y")
axes.xaxis.set_major_locator(day)  # Make x-axis tick interval to be daily interval size
axes.xaxis.set_major_formatter(dayFmt)
axes.xaxis.grid(which='major')

# Format the y-axis
y_major_ticks = MultipleLocator(20)
axes.yaxis.set_major_locator(y_major_ticks)
axes.yaxis.set_ticks_position('right')  # Not sure why 'both' don't work
axes.yaxis.set_label_position('right')
axes.yaxis.grid(which='major')

# Plot the data...
axes.plot_date([datetime.date(time) for time in last2months.index], last2months.values, 'r')
axes.set_title("Current Value@"+current_date+": "+str(current_price), weight="bold", size=10)
# MATPLOTLIB does not have a good way of creating a title with 2 rows of text with different font sizes
# Below is a workaround(http://matplotlib.org/users/text_intro.html), sort of "hackish" and requires trial and error (x,y)
axes.text(.22,1.07, "Last 2 Calendar Months of Bitcoin Values in US$", transform=axes.transAxes,
             weight="bold", size=14)
axes.set_xlabel("Month - Day - Year")
axes.set_ylabel("US$")
plt.setp(axes.get_xticklabels(), rotation=-90, size=8)
plt.setp(axes.get_yticklabels(), size=9)
plt.show()

# %% [markdown]
# ###  Let's generate datetime values and random values

# %%
rng = pd.date_range('1/1/2011', periods=20, freq='D')
data = randn(20)

# %%
type(rng[0])
# Out:
# pandas.tslib.Timestamp

# %%
for x in rng:
    print(x)
# Out:
# 2011-01-01 00:00:00
# 2011-01-02 00:00:00
# 2011-01-03 00:00:00
# 2011-01-04 00:00:00
# 2011-01-05 00:00:00
# 2011-01-06 00:00:00
# 2011-01-07 00:00:00
# 2011-01-08 00:00:00
# 2011-01-09 00:00:00
# 2011-01-10 00:00:00
# 2011-01-11 00:00:00
# 2011-01-12 00:00:00
# 2011-01-13 00:00:00
# 2011-01-14 00:00:00
# 2011-01-15 00:00:00
# 2011-01-16 00:00:00
# 2011-01-17 00:00:00
# 2011-01-18 00:00:00
# 2011-01-19 00:00:00
# 2011-01-20 00:00:00

# %%
data
# Out:
# array([-0.22661085, -0.08595227, -0.89507075,  0.05871042, -0.32782012,
#         1.01084978, -1.82921388, -1.01151501, -1.12330333,  2.44669487,
#        -0.18266027,  1.39477793,  1.35811541,  1.04455482,  1.34366682,
#        -2.57558753, -0.96050292,  1.4123055 , -0.2792445 , -0.56477206])

# %% [markdown]
# ### If I convert x values from type datetime to date, it will plot:

# %%
plt.plot_date([datetime.date(x) for x in rng],data,'r')
plt.show()

# %% [markdown]
# ### But if I plot the x values as datetime, the plot does not show up:

# %%
plt.plot_date(rng,data,'r')
plt.show()
