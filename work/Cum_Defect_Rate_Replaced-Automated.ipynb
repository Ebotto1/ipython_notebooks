# %%
import pyodbc                # Needed to connect to ODBC data sources
import crypto, codecs
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib.ticker import MultipleLocator
import pandas as pd
plt.style.use('ggplot')

key = codecs.escape_decode(open(r'D:\webapps\_server\pyodbc\key', 'r').read())[0]
pw_file = open(r'D:\webapps\_server\pyodbc\cmq.txt', 'r')
pwd = pw_file.read()
pw = crypto.decrypt_with_key(key, pwd)
userid = 'rb10'
pw_file.close()

cnxn_string = 'DSN=CMQ_PROD;UID=' + userid + ';PWD=' + pw

cnxn = pyodbc.connect(cnxn_string)
cursor = cnxn.cursor()

sql = """
WITH VEHICLES as (
SELECT
VIN_SK

FROM CMQ.V_FACT_VHCL_PRDN_SLS prod

INNER join CMQ.V_DIM_MTO MTO
ON prod.mto_sk = mto.mto_sk

WHERE
MTO.MDL_YR IN(2013,2014)
AND MTO.FCTRY_CD = 'ELP'
AND MTO.MDL_NM = 'CRV'
AND MTO.DEST_CD IN('KA','KL')
),

CLAIMS AS (
SELECT
CLAIMS.CLM_SK,
CLAIMS.VIN_SK

FROM CMQ.V_FACT_CLM_TRX CLAIMS

INNER JOIN CMQ.V_DIM_CLM CLAIM_DETAILS
ON CLAIMS.CLM_SK = CLAIM_DETAILS.CLM_SK

INNER JOIN CMQ.V_DIM_MTO MTO
ON CLAIMS.MTO_SK = MTO.MTO_SK

INNER JOIN CMQ.V_DIM_PART FAIL_PART
ON CLAIMS.FAIL_PART_SK = FAIL_PART.PART_SK

INNER JOIN CMQ.V_DIM_SUBL_CD SUBLET1
ON CLAIMS.SUBL_01_SK = SUBLET1.SUBL_CD_SK

INNER JOIN CMQ.V_DIM_SUBL_CD SUBLET2
ON CLAIMS.SUBL_02_SK = SUBLET2.SUBL_CD_SK

WHERE
MTO.MDL_YR IN(2013,2014)
AND MTO.FCTRY_CD = 'ELP'
AND MTO.MDL_NM = 'CRV'
AND MTO.DEST_CD IN('KA','KL')
--AND CLAIM_DETAILS.ORIG_CUST_CNTN_TXT LIKE '%NOISE%'
AND CLAIMS.CAMP_SK <= 0
AND NOT LEFT(CLAIM_DETAILS.CLM_NO,1) IN ('T', 'R')
AND NOT LEFT(FAIL_PART.PART_NO,2) = '08'
AND NOT FAIL_PART.SHRT_PART_NO IN ('TCHV','TCAV')
AND NOT SUBLET1.SUBL_CD = 'GW'
AND NOT SUBLET2.SUBL_CD = 'GW'
),

REPLACED as (
SELECT
REPLPART.CLM_SK

FROM CMQ.V_FACT_CLM_REPL_PART REPLPART

INNER JOIN CLAIMS CLAIMS
ON REPLPART.CLM_SK = CLAIMS.CLM_SK

INNER JOIN CMQ.V_DIM_PART PART
ON PART.PART_SK = REPLPART.REPL_PART_SK

WHERE
PART.SHRT_PART_NO IN('37820')
AND REPLPART.REPL_PART_QTY > 0
AND REPLPART.ADJ_PART_QTY > 0
AND REPLPART.VHCL_DEST_CD IN('KA','KL')
)

SELECT
MDL_YR,
FCTRY_CD,
MDL_NM,
RO_MTH,
SUM(SALE_QTY) AS SALE_QTY,
SUM(VEH_QTY) AS VEH_QTY,
SUM(CLAIM_QTY) AS CLAIM_QTY,
SUM(CLAIM_AMT) AS CLAIM_AMT

FROM (
    SELECT
    MDL_YR,
    FCTRY_CD,
    MDL_NM,
    RO_MTH,
    SUM(SALE_QTY) AS SALE_QTY,
    SUM(VEH_QTY) AS VEH_QTY,
    SUM(CLAIM_QTY) AS CLAIM_QTY,
    SUM(CLAIM_AMT) AS CLAIM_AMT

    FROM (
        SELECT
        MTO.MDL_YR AS MDL_YR,
        MTO.FCTRY_CD AS FCTRY_CD,
        MTO.MDL_NM AS MDL_NM,
        SALE_CAL.CAL_YR_MO_FMT_NO AS RO_MTH,

        CASE
        WHEN PROD.RTL_SLS_DT_SK > 0
        THEN 1
        ELSE 0
        END AS SALE_QTY,

        1 AS VEH_QTY,
        0 AS CLAIM_QTY,
        0 AS CLAIM_AMT

        FROM VEHICLES VEHICLES

        INNER JOIN CMQ.V_FACT_VHCL_PRDN_SLS PROD
        ON VEHICLES.VIN_SK = PROD.VIN_SK

        INNER JOIN CMQ.V_DIM_MTO MTO
        ON PROD.MTO_SK = MTO.MTO_SK

        INNER JOIN CMQ.V_DIM_DATE SALE_CAL
        ON PROD.RTL_SLS_DT_SK = SALE_CAL.CAL_DT_SK

        WHERE
        VEHICLES.VIN_SK IS NOT NULL

    ) AS VEH

    GROUP BY
    MDL_YR,
    FCTRY_CD,
    MDL_NM,
    RO_MTH

    UNION

    SELECT
    MDL_YR,
    FCTRY_CD,
    MDL_NM,
    RO_MTH,
    SUM(SALE_QTY) AS SALE_QTY,
    SUM(VEH_QTY) AS VEH_QTY,
    SUM(CLAIM_QTY) AS CLAIM_QTY,
    SUM(CLAIM_AMT) AS CLAIM_AMT

    FROM (
        SELECT
        MTO.MDL_YR AS MDL_YR,
        MTO.FCTRY_CD AS FCTRY_CD,
        MTO.MDL_NM AS MDL_NM,
        RO_CAL.CAL_YR_MO_FMT_NO AS RO_MTH,

        0 AS SALE_QTY,

        0 AS VEH_QTY,
        1 AS CLAIM_QTY,
        FCLAIMS.USD_REMB_CLM_AMT AS CLAIM_AMT

        FROM CLAIMS CLAIMS

        INNER JOIN REPLACED
        ON CLAIMS.CLM_SK = REPLACED.CLM_SK

        INNER JOIN CMQ.V_FACT_VHCL_PRDN_SLS PROD
        ON CLAIMS.VIN_SK = PROD.VIN_SK

        INNER JOIN CMQ.V_FACT_CLM_TRX FCLAIMS
        ON CLAIMS.CLM_SK = FCLAIMS.CLM_SK

        INNER JOIN CMQ.V_DIM_MTO MTO
        ON PROD.MTO_SK = MTO.MTO_SK

        INNER JOIN CMQ.V_DIM_DATE RO_CAL
        ON FCLAIMS.RO_DT_SK = RO_CAL.CAL_DT_SK

        WHERE
        CLAIMS.CLM_SK IS NOT NULL

    ) AS CLM

    GROUP BY
    MDL_YR,
    FCTRY_CD,
    MDL_NM,
    RO_MTH

) AS FINAL

GROUP BY
MDL_YR,
FCTRY_CD,
MDL_NM,
RO_MTH
"""

df = pd.read_sql(sql, cnxn, index_col=None)

# Close connections
cursor.close()
cnxn.close()

# Exclude unsold units
df = df[df['RO_MTH']!='9999-12']

# %%
df
# Out:
#     MDL_YR FCTRY_CD MDL_NM   RO_MTH  SALE_QTY  VEH_QTY  CLAIM_QTY  CLAIM_AMT
# 0     2013      ELP    CRV  2012-09      2117     2117          2    1251.51
# 1     2013      ELP    CRV  2012-10      9532     9532          0       0.00
# 2     2013      ELP    CRV  2012-11     11266    11266          0       0.00
# 3     2013      ELP    CRV  2012-12     12266    12266          0       0.00
# 4     2013      ELP    CRV  2013-01      9892     9892          0       0.00
# 5     2013      ELP    CRV  2013-02     11248    11248          0       0.00
# 6     2013      ELP    CRV  2013-03     14369    14369          1     822.95
# 7     2013      ELP    CRV  2013-04     15058    15058          1     571.98
# 8     2013      ELP    CRV  2013-05     14097    14097          2    2259.88
# 9     2013      ELP    CRV  2013-06     12337    12337          2     958.33
# 10    2013      ELP    CRV  2013-07     12039    12039          3    1735.88
# 11    2013      ELP    CRV  2013-08     10773    10773          1     530.25
# 12    2013      ELP    CRV  2013-09      2492     2492          4    3373.52
# 13    2013      ELP    CRV  2013-10       637      637          2    1258.31
# 14    2013      ELP    CRV  2013-11       341      341          0       0.00
# 15    2013      ELP    CRV  2013-12       210      210          2    1828.76
# 16    2013      ELP    CRV  2014-01        84       84          0       0.00
# 17    2013      ELP    CRV  2014-02        62       62          0       0.00
# 18    2013      ELP    CRV  2014-03        42       42          0       0.00
# 19    2013      ELP    CRV  2014-04        22       22          0       0.00
# 20    2013      ELP    CRV  2014-05        19       19          1     546.14
# 21    2013      ELP    CRV  2014-06         7        7          6    4467.58
# 22    2013      ELP    CRV  2014-07         9        9          2    1320.45
# 23    2013      ELP    CRV  2014-08         7        7          1     725.20
# 24    2013      ELP    CRV  2014-09         7        7          1     761.06
# 25    2013      ELP    CRV  2014-10         4        4          1     899.06
# 26    2013      ELP    CRV  2014-11         4        4          0       0.00
# 28    2014      ELP    CRV  2013-08      1864     1864          0       0.00
# 29    2014      ELP    CRV  2013-09      8083     8083          0       0.00
# 30    2014      ELP    CRV  2013-10     10742    10742          0       0.00
# 31    2014      ELP    CRV  2013-11     10462    10462          0       0.00
# 32    2014      ELP    CRV  2013-12     12563    12563          1    1816.07
# 33    2014      ELP    CRV  2014-01      8983     8983          2    1357.37
# 34    2014      ELP    CRV  2014-02      9584     9584          2    1305.86
# 35    2014      ELP    CRV  2014-03     13395    13395          3    4762.91
# 36    2014      ELP    CRV  2014-04     13615    13615          1     489.46
# 37    2014      ELP    CRV  2014-05     14068    14068          3    2246.18
# 38    2014      ELP    CRV  2014-06     12329    12329          3    1865.33
# 39    2014      ELP    CRV  2014-07     11481    11481          1     889.61
# 40    2014      ELP    CRV  2014-08     11648    11648          0       0.00
# 41    2014      ELP    CRV  2014-09     10613    10613          5    2574.28
# 42    2014      ELP    CRV  2014-10      8010     8010          3    3717.58
# 43    2014      ELP    CRV  2014-11      4438     4438          0       0.00
# 44    2014      ELP    CRV  2014-12       769      769          0       0.00

# %%
df['LABEL'] = df['MDL_YR'].map(str) + '-' + df['MDL_NM'].map(str) + '-' +df['FCTRY_CD'].map(str)

# %%
df
# Out:
#     MDL_YR FCTRY_CD MDL_NM   RO_MTH  SALE_QTY  VEH_QTY  CLAIM_QTY  CLAIM_AMT  \
# 0     2013      ELP    CRV  2012-09      2117     2117          2    1251.51
# 1     2013      ELP    CRV  2012-10      9532     9532          0       0.00
# 2     2013      ELP    CRV  2012-11     11266    11266          0       0.00
# 3     2013      ELP    CRV  2012-12     12266    12266          0       0.00
# 4     2013      ELP    CRV  2013-01      9892     9892          0       0.00
# 5     2013      ELP    CRV  2013-02     11248    11248          0       0.00
# 6     2013      ELP    CRV  2013-03     14369    14369          1     822.95
# 7     2013      ELP    CRV  2013-04     15058    15058          1     571.98
# 8     2013      ELP    CRV  2013-05     14097    14097          2    2259.88
# 9     2013      ELP    CRV  2013-06     12337    12337          2     958.33
# 10    2013      ELP    CRV  2013-07     12039    12039          3    1735.88
# 11    2013      ELP    CRV  2013-08     10773    10773          1     530.25
# 12    2013      ELP    CRV  2013-09      2492     2492          4    3373.52
# 13    2013      ELP    CRV  2013-10       637      637          2    1258.31
# 14    2013      ELP    CRV  2013-11       341      341          0       0.00
# 15    2013      ELP    CRV  2013-12       210      210          2    1828.76
# 16    2013      ELP    CRV  2014-01        84       84          0       0.00
# 17    2013      ELP    CRV  2014-02        62       62          0       0.00
# 18    2013      ELP    CRV  2014-03        42       42          0       0.00
# 19    2013      ELP    CRV  2014-04        22       22          0       0.00
# 20    2013      ELP    CRV  2014-05        19       19          1     546.14
# 21    2013      ELP    CRV  2014-06         7        7          6    4467.58
# 22    2013      ELP    CRV  2014-07         9        9          2    1320.45
# 23    2013      ELP    CRV  2014-08         7        7          1     725.20
# 24    2013      ELP    CRV  2014-09         7        7          1     761.06
# 25    2013      ELP    CRV  2014-10         4        4          1     899.06
# 26    2013      ELP    CRV  2014-11         4        4          0       0.00
# 28    2014      ELP    CRV  2013-08      1864     1864          0       0.00
# 29    2014      ELP    CRV  2013-09      8083     8083          0       0.00
# 30    2014      ELP    CRV  2013-10     10742    10742          0       0.00
# 31    2014      ELP    CRV  2013-11     10462    10462          0       0.00
# 32    2014      ELP    CRV  2013-12     12563    12563          1    1816.07
# 33    2014      ELP    CRV  2014-01      8983     8983          2    1357.37
# 34    2014      ELP    CRV  2014-02      9584     9584          2    1305.86
# 35    2014      ELP    CRV  2014-03     13395    13395          3    4762.91
# 36    2014      ELP    CRV  2014-04     13615    13615          1     489.46
# 37    2014      ELP    CRV  2014-05     14068    14068          3    2246.18
# 38    2014      ELP    CRV  2014-06     12329    12329          3    1865.33
# 39    2014      ELP    CRV  2014-07     11481    11481          1     889.61
# 40    2014      ELP    CRV  2014-08     11648    11648          0       0.00
# 41    2014      ELP    CRV  2014-09     10613    10613          5    2574.28
# 42    2014      ELP    CRV  2014-10      8010     8010          3    3717.58
# 43    2014      ELP    CRV  2014-11      4438     4438          0       0.00
# 44    2014      ELP    CRV  2014-12       769      769          0       0.00
#
#            LABEL
# 0   2013-CRV-ELP
# 1   2013-CRV-ELP
# 2   2013-CRV-ELP
# 3   2013-CRV-ELP
# 4   2013-CRV-ELP
# 5   2013-CRV-ELP
# 6   2013-CRV-ELP
# 7   2013-CRV-ELP
# 8   2013-CRV-ELP
# 9   2013-CRV-ELP
# 10  2013-CRV-ELP
# 11  2013-CRV-ELP
# 12  2013-CRV-ELP
# 13  2013-CRV-ELP
# 14  2013-CRV-ELP
# 15  2013-CRV-ELP
# 16  2013-CRV-ELP
# 17  2013-CRV-ELP
# 18  2013-CRV-ELP
# 19  2013-CRV-ELP
# 20  2013-CRV-ELP
# 21  2013-CRV-ELP
# 22  2013-CRV-ELP
# 23  2013-CRV-ELP
# 24  2013-CRV-ELP
# 25  2013-CRV-ELP
# 26  2013-CRV-ELP
# 28  2014-CRV-ELP
# 29  2014-CRV-ELP
# 30  2014-CRV-ELP
# 31  2014-CRV-ELP
# 32  2014-CRV-ELP
# 33  2014-CRV-ELP
# 34  2014-CRV-ELP
# 35  2014-CRV-ELP
# 36  2014-CRV-ELP
# 37  2014-CRV-ELP
# 38  2014-CRV-ELP
# 39  2014-CRV-ELP
# 40  2014-CRV-ELP
# 41  2014-CRV-ELP
# 42  2014-CRV-ELP
# 43  2014-CRV-ELP
# 44  2014-CRV-ELP

# %%
dfTemp = df.copy()

# %%
cum_sales = pd.pivot_table(dfTemp,values='SALE_QTY',index='RO_MTH',columns=['LABEL'],aggfunc=np.sum).cumsum()

# %%
cum_sales
# Out:
# LABEL    2013-CRV-ELP  2014-CRV-ELP
# RO_MTH
# 2012-09          2117           NaN
# 2012-10         11649           NaN
# 2012-11         22915           NaN
# 2012-12         35181           NaN
# 2013-01         45073           NaN
# 2013-02         56321           NaN
# 2013-03         70690           NaN
# 2013-04         85748           NaN
# 2013-05         99845           NaN
# 2013-06        112182           NaN
# 2013-07        124221           NaN
# 2013-08        134994          1864
# 2013-09        137486          9947
# 2013-10        138123         20689
# 2013-11        138464         31151
# 2013-12        138674         43714
# 2014-01        138758         52697
# 2014-02        138820         62281
# 2014-03        138862         75676
# 2014-04        138884         89291
# 2014-05        138903        103359
# 2014-06        138910        115688
# 2014-07        138919        127169
# 2014-08        138926        138817
# 2014-09        138933        149430
# 2014-10        138937        157440
# 2014-11        138941        161878
# 2014-12           NaN        162647

# %%
cum_sales.columns = [column + ' Cum Sales' for column in cum_sales.columns]

# %%
cum_sales
# Out:
#          2013-CRV-ELP Cum Sales  2014-CRV-ELP Cum Sales
# RO_MTH
# 2012-09                    2117                     NaN
# 2012-10                   11649                     NaN
# 2012-11                   22915                     NaN
# 2012-12                   35181                     NaN
# 2013-01                   45073                     NaN
# 2013-02                   56321                     NaN
# 2013-03                   70690                     NaN
# 2013-04                   85748                     NaN
# 2013-05                   99845                     NaN
# 2013-06                  112182                     NaN
# 2013-07                  124221                     NaN
# 2013-08                  134994                    1864
# 2013-09                  137486                    9947
# 2013-10                  138123                   20689
# 2013-11                  138464                   31151
# 2013-12                  138674                   43714
# 2014-01                  138758                   52697
# 2014-02                  138820                   62281
# 2014-03                  138862                   75676
# 2014-04                  138884                   89291
# 2014-05                  138903                  103359
# 2014-06                  138910                  115688
# 2014-07                  138919                  127169
# 2014-08                  138926                  138817
# 2014-09                  138933                  149430
# 2014-10                  138937                  157440
# 2014-11                  138941                  161878
# 2014-12                     NaN                  162647

# %%
cum_claims = pd.pivot_table(dfTemp,values='CLAIM_QTY',index='RO_MTH',columns=['LABEL'],aggfunc=np.sum).cumsum()

# %%
cum_claims
# Out:
# LABEL    2013-CRV-ELP  2014-CRV-ELP
# RO_MTH
# 2012-09             2           NaN
# 2012-10             2           NaN
# 2012-11             2           NaN
# 2012-12             2           NaN
# 2013-01             2           NaN
# 2013-02             2           NaN
# 2013-03             3           NaN
# 2013-04             4           NaN
# 2013-05             6           NaN
# 2013-06             8           NaN
# 2013-07            11           NaN
# 2013-08            12             0
# 2013-09            16             0
# 2013-10            18             0
# 2013-11            18             0
# 2013-12            20             1
# 2014-01            20             3
# 2014-02            20             5
# 2014-03            20             8
# 2014-04            20             9
# 2014-05            21            12
# 2014-06            27            15
# 2014-07            29            16
# 2014-08            30            16
# 2014-09            31            21
# 2014-10            32            24
# 2014-11            32            24
# 2014-12           NaN            24

# %%
cum_claims.columns = [column + ' Cum Claims' for column in cum_claims.columns]

# %%
cum_claims
# Out:
#          2013-CRV-ELP Cum Claims  2014-CRV-ELP Cum Claims
# RO_MTH
# 2012-09                        2                      NaN
# 2012-10                        2                      NaN
# 2012-11                        2                      NaN
# 2012-12                        2                      NaN
# 2013-01                        2                      NaN
# 2013-02                        2                      NaN
# 2013-03                        3                      NaN
# 2013-04                        4                      NaN
# 2013-05                        6                      NaN
# 2013-06                        8                      NaN
# 2013-07                       11                      NaN
# 2013-08                       12                        0
# 2013-09                       16                        0
# 2013-10                       18                        0
# 2013-11                       18                        0
# 2013-12                       20                        1
# 2014-01                       20                        3
# 2014-02                       20                        5
# 2014-03                       20                        8
# 2014-04                       20                        9
# 2014-05                       21                       12
# 2014-06                       27                       15
# 2014-07                       29                       16
# 2014-08                       30                       16
# 2014-09                       31                       21
# 2014-10                       32                       24
# 2014-11                       32                       24
# 2014-12                      NaN                       24

# %%
left_joined = pd.merge(cum_sales,cum_claims,how='left',left_index=True,right_index=True)

# %%
left_joined
# Out:
#          2013-CRV-ELP Cum Sales  2014-CRV-ELP Cum Sales  \
# RO_MTH
# 2012-09                    2117                     NaN
# 2012-10                   11649                     NaN
# 2012-11                   22915                     NaN
# 2012-12                   35181                     NaN
# 2013-01                   45073                     NaN
# 2013-02                   56321                     NaN
# 2013-03                   70690                     NaN
# 2013-04                   85748                     NaN
# 2013-05                   99845                     NaN
# 2013-06                  112182                     NaN
# 2013-07                  124221                     NaN
# 2013-08                  134994                    1864
# 2013-09                  137486                    9947
# 2013-10                  138123                   20689
# 2013-11                  138464                   31151
# 2013-12                  138674                   43714
# 2014-01                  138758                   52697
# 2014-02                  138820                   62281
# 2014-03                  138862                   75676
# 2014-04                  138884                   89291
# 2014-05                  138903                  103359
# 2014-06                  138910                  115688
# 2014-07                  138919                  127169
# 2014-08                  138926                  138817
# 2014-09                  138933                  149430
# 2014-10                  138937                  157440
# 2014-11                  138941                  161878
# 2014-12                     NaN                  162647
#
#          2013-CRV-ELP Cum Claims  2014-CRV-ELP Cum Claims
# RO_MTH
# 2012-09                        2                      NaN
# 2012-10                        2                      NaN
# 2012-11                        2                      NaN
# 2012-12                        2                      NaN
# 2013-01                        2                      NaN
# 2013-02                        2                      NaN
# 2013-03                        3                      NaN
# 2013-04                        4                      NaN
# 2013-05                        6                      NaN
# 2013-06                        8                      NaN
# 2013-07                       11                      NaN
# 2013-08                       12                        0
# 2013-09                       16                        0
# 2013-10                       18                        0
# 2013-11                       18                        0
# 2013-12                       20                        1
# 2014-01                       20                        3
# 2014-02                       20                        5
# 2014-03                       20                        8
# 2014-04                       20                        9
# 2014-05                       21                       12
# 2014-06                       27                       15
# 2014-07                       29                       16
# 2014-08                       30                       16
# 2014-09                       31                       21
# 2014-10                       32                       24
# 2014-11                       32                       24
# 2014-12                      NaN                       24

# %%
left_joined['Cum_Defect 13M'] = left_joined['2013-CRV-ELP Cum Claims'] / left_joined['2013-CRV-ELP Cum Sales'] * 100

# %%
left_joined
# Out:
#          2013-CRV-ELP Cum Sales  2014-CRV-ELP Cum Sales  \
# RO_MTH
# 2012-09                    2117                     NaN
# 2012-10                   11649                     NaN
# 2012-11                   22915                     NaN
# 2012-12                   35181                     NaN
# 2013-01                   45073                     NaN
# 2013-02                   56321                     NaN
# 2013-03                   70690                     NaN
# 2013-04                   85748                     NaN
# 2013-05                   99845                     NaN
# 2013-06                  112182                     NaN
# 2013-07                  124221                     NaN
# 2013-08                  134994                    1864
# 2013-09                  137486                    9947
# 2013-10                  138123                   20689
# 2013-11                  138464                   31151
# 2013-12                  138674                   43714
# 2014-01                  138758                   52697
# 2014-02                  138820                   62281
# 2014-03                  138862                   75676
# 2014-04                  138884                   89291
# 2014-05                  138903                  103359
# 2014-06                  138910                  115688
# 2014-07                  138919                  127169
# 2014-08                  138926                  138817
# 2014-09                  138933                  149430
# 2014-10                  138937                  157440
# 2014-11                  138941                  161878
# 2014-12                     NaN                  162647
#
#          2013-CRV-ELP Cum Claims  2014-CRV-ELP Cum Claims  Cum_Defect 13M
# RO_MTH
# 2012-09                        2                      NaN        0.094473
# 2012-10                        2                      NaN        0.017169
# 2012-11                        2                      NaN        0.008728
# 2012-12                        2                      NaN        0.005685
# 2013-01                        2                      NaN        0.004437
# 2013-02                        2                      NaN        0.003551
# 2013-03                        3                      NaN        0.004244
# 2013-04                        4                      NaN        0.004665
# 2013-05                        6                      NaN        0.006009
# 2013-06                        8                      NaN        0.007131
# 2013-07                       11                      NaN        0.008855
# 2013-08                       12                        0        0.008889
# 2013-09                       16                        0        0.011638
# 2013-10                       18                        0        0.013032
# 2013-11                       18                        0        0.013000
# 2013-12                       20                        1        0.014422
# 2014-01                       20                        3        0.014414
# 2014-02                       20                        5        0.014407
# 2014-03                       20                        8        0.014403
# 2014-04                       20                        9        0.014401
# 2014-05                       21                       12        0.015118
# 2014-06                       27                       15        0.019437
# 2014-07                       29                       16        0.020875
# 2014-08                       30                       16        0.021594
# 2014-09                       31                       21        0.022313
# 2014-10                       32                       24        0.023032
# 2014-11                       32                       24        0.023031
# 2014-12                      NaN                       24             NaN

# %%
left_joined['Cum_Defect 14M'] = left_joined['2014-CRV-ELP Cum Claims'] / left_joined['2014-CRV-ELP Cum Sales'] * 100

# %%
left_joined
# Out:
#          2013-CRV-ELP Cum Sales  2014-CRV-ELP Cum Sales  \
# RO_MTH
# 2012-09                    2117                     NaN
# 2012-10                   11649                     NaN
# 2012-11                   22915                     NaN
# 2012-12                   35181                     NaN
# 2013-01                   45073                     NaN
# 2013-02                   56321                     NaN
# 2013-03                   70690                     NaN
# 2013-04                   85748                     NaN
# 2013-05                   99845                     NaN
# 2013-06                  112182                     NaN
# 2013-07                  124221                     NaN
# 2013-08                  134994                    1864
# 2013-09                  137486                    9947
# 2013-10                  138123                   20689
# 2013-11                  138464                   31151
# 2013-12                  138674                   43714
# 2014-01                  138758                   52697
# 2014-02                  138820                   62281
# 2014-03                  138862                   75676
# 2014-04                  138884                   89291
# 2014-05                  138903                  103359
# 2014-06                  138910                  115688
# 2014-07                  138919                  127169
# 2014-08                  138926                  138817
# 2014-09                  138933                  149430
# 2014-10                  138937                  157440
# 2014-11                  138941                  161878
# 2014-12                     NaN                  162647
#
#          2013-CRV-ELP Cum Claims  2014-CRV-ELP Cum Claims  Cum_Defect 13M  \
# RO_MTH
# 2012-09                        2                      NaN        0.094473
# 2012-10                        2                      NaN        0.017169
# 2012-11                        2                      NaN        0.008728
# 2012-12                        2                      NaN        0.005685
# 2013-01                        2                      NaN        0.004437
# 2013-02                        2                      NaN        0.003551
# 2013-03                        3                      NaN        0.004244
# 2013-04                        4                      NaN        0.004665
# 2013-05                        6                      NaN        0.006009
# 2013-06                        8                      NaN        0.007131
# 2013-07                       11                      NaN        0.008855
# 2013-08                       12                        0        0.008889
# 2013-09                       16                        0        0.011638
# 2013-10                       18                        0        0.013032
# 2013-11                       18                        0        0.013000
# 2013-12                       20                        1        0.014422
# 2014-01                       20                        3        0.014414
# 2014-02                       20                        5        0.014407
# 2014-03                       20                        8        0.014403
# 2014-04                       20                        9        0.014401
# 2014-05                       21                       12        0.015118
# 2014-06                       27                       15        0.019437
# 2014-07                       29                       16        0.020875
# 2014-08                       30                       16        0.021594
# 2014-09                       31                       21        0.022313
# 2014-10                       32                       24        0.023032
# 2014-11                       32                       24        0.023031
# 2014-12                      NaN                       24             NaN
#
#          Cum_Defect 14M
# RO_MTH
# 2012-09             NaN
# 2012-10             NaN
# 2012-11             NaN
# 2012-12             NaN
# 2013-01             NaN
# 2013-02             NaN
# 2013-03             NaN
# 2013-04             NaN
# 2013-05             NaN
# 2013-06             NaN
# 2013-07             NaN
# 2013-08        0.000000
# 2013-09        0.000000
# 2013-10        0.000000
# 2013-11        0.000000
# 2013-12        0.002288
# 2014-01        0.005693
# 2014-02        0.008028
# 2014-03        0.010571
# 2014-04        0.010079
# 2014-05        0.011610
# 2014-06        0.012966
# 2014-07        0.012582
# 2014-08        0.011526
# 2014-09        0.014053
# 2014-10        0.015244
# 2014-11        0.014826
# 2014-12        0.014756

# %%
defect_rates = left_joined[['Cum_Defect 13M','Cum_Defect 14M']]

# %%
defect_rates
# Out:
#          Cum_Defect 13M  Cum_Defect 14M
# RO_MTH
# 2012-09        0.094473             NaN
# 2012-10        0.017169             NaN
# 2012-11        0.008728             NaN
# 2012-12        0.005685             NaN
# 2013-01        0.004437             NaN
# 2013-02        0.003551             NaN
# 2013-03        0.004244             NaN
# 2013-04        0.004665             NaN
# 2013-05        0.006009             NaN
# 2013-06        0.007131             NaN
# 2013-07        0.008855             NaN
# 2013-08        0.008889        0.000000
# 2013-09        0.011638        0.000000
# 2013-10        0.013032        0.000000
# 2013-11        0.013000        0.000000
# 2013-12        0.014422        0.002288
# 2014-01        0.014414        0.005693
# 2014-02        0.014407        0.008028
# 2014-03        0.014403        0.010571
# 2014-04        0.014401        0.010079
# 2014-05        0.015118        0.011610
# 2014-06        0.019437        0.012966
# 2014-07        0.020875        0.012582
# 2014-08        0.021594        0.011526
# 2014-09        0.022313        0.014053
# 2014-10        0.023032        0.015244
# 2014-11        0.023031        0.014826
# 2014-12             NaN        0.014756

# %%
defect_rates.reset_index(level=0, inplace=True)  # Convert index to column

# %%
df_long = pd.melt(defect_rates, id_vars=['RO_MTH']).dropna()

# %%
df_long
# Out:
#      RO_MTH        variable     value
# 0   2012-09  Cum_Defect 13M  0.094473
# 1   2012-10  Cum_Defect 13M  0.017169
# 2   2012-11  Cum_Defect 13M  0.008728
# 3   2012-12  Cum_Defect 13M  0.005685
# 4   2013-01  Cum_Defect 13M  0.004437
# 5   2013-02  Cum_Defect 13M  0.003551
# 6   2013-03  Cum_Defect 13M  0.004244
# 7   2013-04  Cum_Defect 13M  0.004665
# 8   2013-05  Cum_Defect 13M  0.006009
# 9   2013-06  Cum_Defect 13M  0.007131
# 10  2013-07  Cum_Defect 13M  0.008855
# 11  2013-08  Cum_Defect 13M  0.008889
# 12  2013-09  Cum_Defect 13M  0.011638
# 13  2013-10  Cum_Defect 13M  0.013032
# 14  2013-11  Cum_Defect 13M  0.013000
# 15  2013-12  Cum_Defect 13M  0.014422
# 16  2014-01  Cum_Defect 13M  0.014414
# 17  2014-02  Cum_Defect 13M  0.014407
# 18  2014-03  Cum_Defect 13M  0.014403
# 19  2014-04  Cum_Defect 13M  0.014401
# 20  2014-05  Cum_Defect 13M  0.015118
# 21  2014-06  Cum_Defect 13M  0.019437
# 22  2014-07  Cum_Defect 13M  0.020875
# 23  2014-08  Cum_Defect 13M  0.021594
# 24  2014-09  Cum_Defect 13M  0.022313
# 25  2014-10  Cum_Defect 13M  0.023032
# 26  2014-11  Cum_Defect 13M  0.023031
# 39  2013-08  Cum_Defect 14M  0.000000
# 40  2013-09  Cum_Defect 14M  0.000000
# 41  2013-10  Cum_Defect 14M  0.000000
# 42  2013-11  Cum_Defect 14M  0.000000
# 43  2013-12  Cum_Defect 14M  0.002288
# 44  2014-01  Cum_Defect 14M  0.005693
# 45  2014-02  Cum_Defect 14M  0.008028
# 46  2014-03  Cum_Defect 14M  0.010571
# 47  2014-04  Cum_Defect 14M  0.010079
# 48  2014-05  Cum_Defect 14M  0.011610
# 49  2014-06  Cum_Defect 14M  0.012966
# 50  2014-07  Cum_Defect 14M  0.012582
# 51  2014-08  Cum_Defect 14M  0.011526
# 52  2014-09  Cum_Defect 14M  0.014053
# 53  2014-10  Cum_Defect 14M  0.015244
# 54  2014-11  Cum_Defect 14M  0.014826
# 55  2014-12  Cum_Defect 14M  0.014756

# %%
grouped = df_long['variable'].value_counts()
new_index_list = [[value for value in range(index)] for index in grouped.values]

new_index = []
for mylist in new_index_list:
    new_index = new_index + mylist
    
df_long.index = new_index

# %%
df_long
# Out:
#      RO_MTH        variable     value
# 0   2012-09  Cum_Defect 13M  0.094473
# 1   2012-10  Cum_Defect 13M  0.017169
# 2   2012-11  Cum_Defect 13M  0.008728
# 3   2012-12  Cum_Defect 13M  0.005685
# 4   2013-01  Cum_Defect 13M  0.004437
# 5   2013-02  Cum_Defect 13M  0.003551
# 6   2013-03  Cum_Defect 13M  0.004244
# 7   2013-04  Cum_Defect 13M  0.004665
# 8   2013-05  Cum_Defect 13M  0.006009
# 9   2013-06  Cum_Defect 13M  0.007131
# 10  2013-07  Cum_Defect 13M  0.008855
# 11  2013-08  Cum_Defect 13M  0.008889
# 12  2013-09  Cum_Defect 13M  0.011638
# 13  2013-10  Cum_Defect 13M  0.013032
# 14  2013-11  Cum_Defect 13M  0.013000
# 15  2013-12  Cum_Defect 13M  0.014422
# 16  2014-01  Cum_Defect 13M  0.014414
# 17  2014-02  Cum_Defect 13M  0.014407
# 18  2014-03  Cum_Defect 13M  0.014403
# 19  2014-04  Cum_Defect 13M  0.014401
# 20  2014-05  Cum_Defect 13M  0.015118
# 21  2014-06  Cum_Defect 13M  0.019437
# 22  2014-07  Cum_Defect 13M  0.020875
# 23  2014-08  Cum_Defect 13M  0.021594
# 24  2014-09  Cum_Defect 13M  0.022313
# 25  2014-10  Cum_Defect 13M  0.023032
# 26  2014-11  Cum_Defect 13M  0.023031
# 0   2013-08  Cum_Defect 14M  0.000000
# 1   2013-09  Cum_Defect 14M  0.000000
# 2   2013-10  Cum_Defect 14M  0.000000
# 3   2013-11  Cum_Defect 14M  0.000000
# 4   2013-12  Cum_Defect 14M  0.002288
# 5   2014-01  Cum_Defect 14M  0.005693
# 6   2014-02  Cum_Defect 14M  0.008028
# 7   2014-03  Cum_Defect 14M  0.010571
# 8   2014-04  Cum_Defect 14M  0.010079
# 9   2014-05  Cum_Defect 14M  0.011610
# 10  2014-06  Cum_Defect 14M  0.012966
# 11  2014-07  Cum_Defect 14M  0.012582
# 12  2014-08  Cum_Defect 14M  0.011526
# 13  2014-09  Cum_Defect 14M  0.014053
# 14  2014-10  Cum_Defect 14M  0.015244
# 15  2014-11  Cum_Defect 14M  0.014826
# 16  2014-12  Cum_Defect 14M  0.014756

# %%
from ggplot import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-126-02aeb6e281ab> in <module>()
# ----> 1 from ggplot import *
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\__init__.py in <module>()
#      19 __version__ = '0.6.5'
#      20
# ---> 21 from .qplot import qplot
#      22 from .ggplot import ggplot
#      23 from .components import aes
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\qplot.py in <module>()
#       4 import ggplot
#       5 from .components import aes
# ----> 6 from .geoms import geom_point, geom_bar, geom_boxplot, geom_histogram, geom_line
#       7 from .geoms.chart_components import xlab as xlabel
#       8 from .geoms.chart_components import ylab as ylabel
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\geoms\__init__.py in <module>()
#       2                         unicode_literals)
#       3 # geoms
# ----> 4 from .geom_abline import geom_abline
#       5 from .geom_area import geom_area
#       6 from .geom_bar import geom_bar
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\geoms\geom_abline.py in <module>()
#       4 import numpy as np
#       5 from ggplot.utils import make_iterable_ntimes
# ----> 6 from .geom import geom
#       7
#       8 # Note when documenting
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\geoms\geom.py in <module>()
#       8 from ggplot.utils import is_string
#       9
# ---> 10 import ggplot.stats
#      11 from ggplot.utils import is_scalar_or_string
#      12 from ggplot.components import aes
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\stats\__init__.py in <module>()
#       5 from .stat_bin import stat_bin
#       6 from .stat_bin2d import stat_bin2d
# ----> 7 from .stat_density import stat_density
#       8 from .stat_function import stat_function
#       9 from .stat_hline import stat_hline
#
# D:\Miniconda3\envs\notebook\lib\site-packages\ggplot\stats\stat_density.py in <module>()
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from scipy.stats import gaussian_kde
#       6
#       7 from ggplot.utils import make_iterable_ntimes
#
# D:\Miniconda3\envs\notebook\lib\site-packages\scipy\stats\__init__.py in <module>()
#     332 from __future__ import division, print_function, absolute_import
#     333
# --> 334 from .stats import *
#     335 from .distributions import *
#     336 from .rv import *
#
# D:\Miniconda3\envs\notebook\lib\site-packages\scipy\stats\stats.py in <module>()
#     179 from scipy.lib.six import callable, string_types
#     180 from numpy import array, asarray, ma, zeros, sum
# --> 181 import scipy.special as special
#     182 import scipy.linalg as linalg
#     183 import numpy as np
#
# D:\Miniconda3\envs\notebook\lib\site-packages\scipy\special\__init__.py in <module>()
#     544 from __future__ import division, print_function, absolute_import
#     545
# --> 546 from ._ufuncs import *
#     547
#     548 from .basic import *
#
# ImportError: DLL load failed: The specified procedure could not be found.
