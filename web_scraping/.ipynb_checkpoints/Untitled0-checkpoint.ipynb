# %%
import pandas as pd
import urllib.request as request
from bs4 import BeautifulSoup
import re

base_url = 'http://espn.go.com'

teams_url = 'http://espn.go.com/nba/teams'
html_teams = request.urlopen(teams_url)

soup_teams = BeautifulSoup(html_teams)

# %%
urls = soup_teams.find_all(href=re.compile('/nba/teams/stats'))
urls
# Out:
# [<a href="/nba/teams/stats?team=bos">Stats</a>,
#  <a href="/nba/teams/stats?team=bkn">Stats</a>,
#  <a href="/nba/teams/stats?team=nyk">Stats</a>,
#  <a href="/nba/teams/stats?team=phi">Stats</a>,
#  <a href="/nba/teams/stats?team=tor">Stats</a>,
#  <a href="/nba/teams/stats?team=gsw">Stats</a>,
#  <a href="/nba/teams/stats?team=lac">Stats</a>,
#  <a href="/nba/teams/stats?team=lal">Stats</a>,
#  <a href="/nba/teams/stats?team=pho">Stats</a>,
#  <a href="/nba/teams/stats?team=sac">Stats</a>,
#  <a href="/nba/teams/stats?team=chi">Stats</a>,
#  <a href="/nba/teams/stats?team=cle">Stats</a>,
#  <a href="/nba/teams/stats?team=det">Stats</a>,
#  <a href="/nba/teams/stats?team=ind">Stats</a>,
#  <a href="/nba/teams/stats?team=mil">Stats</a>,
#  <a href="/nba/teams/stats?team=dal">Stats</a>,
#  <a href="/nba/teams/stats?team=hou">Stats</a>,
#  <a href="/nba/teams/stats?team=mem">Stats</a>,
#  <a href="/nba/teams/stats?team=nor">Stats</a>,
#  <a href="/nba/teams/stats?team=sas">Stats</a>,
#  <a href="/nba/teams/stats?team=atl">Stats</a>,
#  <a href="/nba/teams/stats?team=cha">Stats</a>,
#  <a href="/nba/teams/stats?team=mia">Stats</a>,
#  <a href="/nba/teams/stats?team=orl">Stats</a>,
#  <a href="/nba/teams/stats?team=was">Stats</a>,
#  <a href="/nba/teams/stats?team=den">Stats</a>,
#  <a href="/nba/teams/stats?team=min">Stats</a>,
#  <a href="/nba/teams/stats?team=okc">Stats</a>,
#  <a href="/nba/teams/stats?team=por">Stats</a>,
#  <a href="/nba/teams/stats?team=uth">Stats</a>]

# %%
team_name_dict = {'bos':'Boston Celtics',
                  'bkn':'Brooklyn Nets',
                  'nyk':'New York Knicks',
                  'phi':'Philadelphia 76ers',
                  'tor':'Toronto Raptors',
                  'gsw':'Golden State Warriors',
                  'lac':'Los Angeles Clippers',
                  'lal':'Los Angeles Lakers',
                  'pho':'Phoenix Suns',
                  'sac':'Sacramento Kings',
                  'chi':'Chicago Bulls',
                  'cle':'Cleveland Cavaliers',
                  'det':'Detroit Pistons',
                  'ind':'Indiana Pacers',
                  'mil':'Milwaukee Bucks',
                  'dal':'Dallas Mavericks',
                  'hou':'Houston Rockets',
                  'mem':'Memphis Grizzlies',
                  'nor':'New Orleans Pelicans',
                  'sas':'San Antonio Spurs',
                  'atl':'Atlanta Hawks',
                  'cha':'Charlotte Hornets',
                  'mia':'Miami Heat',
                  'orl':'Orlando Magic',
                  'was':'Washington Wizards',
                  'den':'Denver Nuggets',
                  'min':'Minnesota Timberwolves',
                  'okc':'Oklahoma City Thunder',
                  'por':'Portland Trail Blazers',
                  'uth':'Utah Jazz'
                  }

# %%
team_urls = [base_url+url['href'] for url in urls]
team_urls
# Out:
# ['http://espn.go.com/nba/teams/stats?team=bos',
#  'http://espn.go.com/nba/teams/stats?team=bkn',
#  'http://espn.go.com/nba/teams/stats?team=nyk',
#  'http://espn.go.com/nba/teams/stats?team=phi',
#  'http://espn.go.com/nba/teams/stats?team=tor',
#  'http://espn.go.com/nba/teams/stats?team=gsw',
#  'http://espn.go.com/nba/teams/stats?team=lac',
#  'http://espn.go.com/nba/teams/stats?team=lal',
#  'http://espn.go.com/nba/teams/stats?team=pho',
#  'http://espn.go.com/nba/teams/stats?team=sac',
#  'http://espn.go.com/nba/teams/stats?team=chi',
#  'http://espn.go.com/nba/teams/stats?team=cle',
#  'http://espn.go.com/nba/teams/stats?team=det',
#  'http://espn.go.com/nba/teams/stats?team=ind',
#  'http://espn.go.com/nba/teams/stats?team=mil',
#  'http://espn.go.com/nba/teams/stats?team=dal',
#  'http://espn.go.com/nba/teams/stats?team=hou',
#  'http://espn.go.com/nba/teams/stats?team=mem',
#  'http://espn.go.com/nba/teams/stats?team=nor',
#  'http://espn.go.com/nba/teams/stats?team=sas',
#  'http://espn.go.com/nba/teams/stats?team=atl',
#  'http://espn.go.com/nba/teams/stats?team=cha',
#  'http://espn.go.com/nba/teams/stats?team=mia',
#  'http://espn.go.com/nba/teams/stats?team=orl',
#  'http://espn.go.com/nba/teams/stats?team=was',
#  'http://espn.go.com/nba/teams/stats?team=den',
#  'http://espn.go.com/nba/teams/stats?team=min',
#  'http://espn.go.com/nba/teams/stats?team=okc',
#  'http://espn.go.com/nba/teams/stats?team=por',
#  'http://espn.go.com/nba/teams/stats?team=uth']

# %%
url_team = 'http://espn.go.com/nba/teams/stats?team=bos'
team_code = url_team[-3:]
html_team = request.urlopen(url_team)

soup_team = BeautifulSoup(html_team)

roster = soup_team.find_all('tr', class_=re.compile('player'))

# %%
roster_game_stats = roster[:int(len(roster)/2)]
roster_shooting_stats = roster[-int(len(roster)/2):]

# %%
for player in roster_game_stats:
    print(player.get_text())
# Out:
# Jeff Green, SF292933.318.50.73.64.21.60.830.411.72.00.915.7
# Jared Sullinger, PF292927.913.52.35.67.92.30.590.721.22.41.817.6
# Avery Bradley, PG282829.912.30.52.12.71.40.890.211.12.11.310.3
# Kelly Olynyk, C291325.812.11.54.15.62.01.070.791.73.71.217.3
# Tyler Zeller, C291619.29.51.63.75.31.10.280.790.92.61.321.3
# Brandon Bass, PF29018.18.91.12.63.60.80.480.310.81.51.015.8
# Evan Turner, SG29423.68.70.53.33.83.70.930.312.22.11.712.5
# Rajon Rondo, PG†222231.88.31.16.47.510.81.680.143.41.93.215.2
# Marcus Thornton, SG20015.48.20.41.01.40.80.450.250.60.61.415.3
# Marcus Smart, PG16319.35.80.81.62.42.21.060.131.42.11.59.9
# Jae Crowder, SF†5014.65.41.01.22.20.40.600.200.21.02.013.6
# Brandan Wright, PF†5010.24.60.61.42.00.40.200.400.80.60.515.6
# Jameer Nelson, PG†5121.44.40.62.02.66.61.400.001.62.44.19.9
# Phil Pressey, PG19012.72.70.31.31.52.30.790.050.81.22.99.0
# James Young, SG503.62.20.00.40.40.20.000.200.00.20.022.4
# Dwight Powell, PF†501.81.80.00.20.20.00.400.000.40.20.034.2
# Gerald Wallace, SF1307.30.50.20.50.80.20.540.150.40.70.44.1

# %%
for player in roster_shooting_stats:
    print(player.get_text())
# Out:
# Jeff Green, SF6.514.4.4501.64.9.3194.04.80.834.99.5.5161.2820.50
# Jared Sullinger, PF5.612.2.4591.13.2.3511.21.80.664.59.0.4981.1100.51
# Avery Bradley, PG5.112.0.4271.34.0.3190.81.00.823.88.0.4821.0300.48
# Kelly Olynyk, C4.78.9.5211.02.6.3821.82.60.693.76.3.5791.3550.58
# Tyler Zeller, C3.75.9.6320.00.0.0002.12.40.853.75.9.6321.6140.63
# Brandon Bass, PF3.47.2.4810.00.2.0002.02.40.803.47.0.4931.2360.48
# Evan Turner, SG3.67.7.4660.31.0.3331.21.30.893.36.7.4871.1300.49
# Rajon Rondo, PG†3.79.1.4050.41.5.2500.51.60.333.37.6.435.9100.43
# Marcus Thornton, SG3.17.1.4401.12.6.4230.91.10.772.04.5.4491.1560.52
# Marcus Smart, PG1.95.1.3661.13.4.3150.91.30.750.81.7.4641.1220.47
# Jae Crowder, SF†2.04.8.4170.42.0.2001.01.01.001.62.8.5711.1250.46
# Brandan Wright, PF†2.23.6.6110.00.0.0000.20.40.502.23.6.6111.2780.61
# Jameer Nelson, PG†1.46.4.2190.84.2.1900.81.00.800.62.2.273.6880.28
# Phil Pressey, PG0.93.1.3050.31.6.2000.50.70.710.61.5.414.8810.36
# James Young, SG1.01.6.6250.20.6.3330.00.20.000.81.0.8001.3750.69
# Dwight Powell, PF†0.81.0.8000.00.0.0000.20.40.500.81.0.8001.8000.80
# Gerald Wallace, SF0.20.5.2860.00.1.0000.20.30.750.20.4.3331.0000.29

# %%
players = []
for row in roster_game_stats:
    for data in row:
        players.append(data.get_text())
        
player_ids = [player.a['href'].split('/')[7] for player in roster_game_stats]

# %%
for player in players:
    print(player)
# Out:
# Jeff Green, SF
# 29
# 29
# 33.3
# 18.5
# 0.7
# 3.6
# 4.2
# 1.6
# 0.83
# 0.41
# 1.7
# 2.0
# 0.9
# 15.7
# Jared Sullinger, PF
# 29
# 29
# 27.9
# 13.5
# 2.3
# 5.6
# 7.9
# 2.3
# 0.59
# 0.72
# 1.2
# 2.4
# 1.8
# 17.6
# Avery Bradley, PG
# 28
# 28
# 29.9
# 12.3
# 0.5
# 2.1
# 2.7
# 1.4
# 0.89
# 0.21
# 1.1
# 2.1
# 1.3
# 10.3
# Kelly Olynyk, C
# 29
# 13
# 25.8
# 12.1
# 1.5
# 4.1
# 5.6
# 2.0
# 1.07
# 0.79
# 1.7
# 3.7
# 1.2
# 17.3
# Tyler Zeller, C
# 29
# 16
# 19.2
# 9.5
# 1.6
# 3.7
# 5.3
# 1.1
# 0.28
# 0.79
# 0.9
# 2.6
# 1.3
# 21.3
# Brandon Bass, PF
# 29
# 0
# 18.1
# 8.9
# 1.1
# 2.6
# 3.6
# 0.8
# 0.48
# 0.31
# 0.8
# 1.5
# 1.0
# 15.8
# Evan Turner, SG
# 29
# 4
# 23.6
# 8.7
# 0.5
# 3.3
# 3.8
# 3.7
# 0.93
# 0.31
# 2.2
# 2.1
# 1.7
# 12.5
# Rajon Rondo, PG†
# 22
# 22
# 31.8
# 8.3
# 1.1
# 6.4
# 7.5
# 10.8
# 1.68
# 0.14
# 3.4
# 1.9
# 3.2
# 15.2
# Marcus Thornton, SG
# 20
# 0
# 15.4
# 8.2
# 0.4
# 1.0
# 1.4
# 0.8
# 0.45
# 0.25
# 0.6
# 0.6
# 1.4
# 15.3
# Marcus Smart, PG
# 16
# 3
# 19.3
# 5.8
# 0.8
# 1.6
# 2.4
# 2.2
# 1.06
# 0.13
# 1.4
# 2.1
# 1.5
# 9.9
# Jae Crowder, SF†
# 5
# 0
# 14.6
# 5.4
# 1.0
# 1.2
# 2.2
# 0.4
# 0.60
# 0.20
# 0.2
# 1.0
# 2.0
# 13.6
# Brandan Wright, PF†
# 5
# 0
# 10.2
# 4.6
# 0.6
# 1.4
# 2.0
# 0.4
# 0.20
# 0.40
# 0.8
# 0.6
# 0.5
# 15.6
# Jameer Nelson, PG†
# 5
# 1
# 21.4
# 4.4
# 0.6
# 2.0
# 2.6
# 6.6
# 1.40
# 0.00
# 1.6
# 2.4
# 4.1
# 9.9
# Phil Pressey, PG
# 19
# 0
# 12.7
# 2.7
# 0.3
# 1.3
# 1.5
# 2.3
# 0.79
# 0.05
# 0.8
# 1.2
# 2.9
# 9.0
# James Young, SG
# 5
# 0
# 3.6
# 2.2
# 0.0
# 0.4
# 0.4
# 0.2
# 0.00
# 0.20
# 0.0
# 0.2
# 0.0
# 22.4
# Dwight Powell, PF†
# 5
# 0
# 1.8
# 1.8
# 0.0
# 0.2
# 0.2
# 0.0
# 0.40
# 0.00
# 0.4
# 0.2
# 0.0
# 34.2
# Gerald Wallace, SF
# 13
# 0
# 7.3
# 0.5
# 0.2
# 0.5
# 0.8
# 0.2
# 0.54
# 0.15
# 0.4
# 0.7
# 0.4
# 4.1

# %%
player_label = players[0::15]
player_label
# Out:
# ['Jeff Green, SF',
#  'Jared Sullinger, PF',
#  'Avery Bradley, PG',
#  'Kelly Olynyk, C',
#  'Tyler Zeller, C',
#  'Brandon Bass, PF',
#  'Evan Turner, SG',
#  'Rajon Rondo, PG†',
#  'Marcus Thornton, SG',
#  'Marcus Smart, PG',
#  'Jae Crowder, SF†',
#  'Brandan Wright, PF†',
#  'Jameer Nelson, PG†',
#  'Phil Pressey, PG',
#  'James Young, SG',
#  'Dwight Powell, PF†',
#  'Gerald Wallace, SF']

# %%
player_name = [player.split(',')[0] for player in player_label]
player_name
# Out:
# ['Jeff Green',
#  'Jared Sullinger',
#  'Avery Bradley',
#  'Kelly Olynyk',
#  'Tyler Zeller',
#  'Brandon Bass',
#  'Evan Turner',
#  'Rajon Rondo',
#  'Marcus Thornton',
#  'Marcus Smart',
#  'Jae Crowder',
#  'Brandan Wright',
#  'Jameer Nelson',
#  'Phil Pressey',
#  'James Young',
#  'Dwight Powell',
#  'Gerald Wallace']

# %%
player_position = [player.split(',')[1].replace('†','').strip() for player in player_label]
player_position
# Out:
# ['SF',
#  'PF',
#  'PG',
#  'C',
#  'C',
#  'PF',
#  'SG',
#  'PG',
#  'SG',
#  'PG',
#  'SF',
#  'PF',
#  'PG',
#  'PG',
#  'SG',
#  'PF',
#  'SF']

# %%
index = 0
increment = 0
for id in player_ids:
    players.insert(index + increment, id)
    index = index + 15
    increment = increment + 1

# %%
L3 = ['a','b','c','a','b','c']

# %%
del L3[0::3]

# %%
L3
# Out:
# ['b', 'c', 'b', 'c']

# %%
player_ids
# Out:
# ['3209',
#  '6624',
#  '4240',
#  '2489663',
#  '6631',
#  '2745',
#  '4239',
#  '3026',
#  '4017',
#  '2990992',
#  '6581',
#  '3242',
#  '2439',
#  '2530722',
#  '3064509',
#  '2531367',
#  '1026']

# %%
len(players)/16
# Out:
# 17.0

# %%
17*16
# Out:
# 272

# %%
players
# Out:
# ['3209',
#  'Jeff Green, SF',
#  'bos',
#  '29',
#  '29',
#  '33.3',
#  '18.5',
#  '0.7',
#  '3.6',
#  '4.2',
#  '1.6',
#  '0.83',
#  '0.41',
#  '1.7',
#  '2.0',
#  '0.9',
#  '15.7',
#  '6624',
#  'Jared Sullinger, PF',
#  'bos',
#  '29',
#  '29',
#  '27.9',
#  '13.5',
#  '2.3',
#  '5.6',
#  '7.9',
#  '2.3',
#  '0.59',
#  '0.72',
#  '1.2',
#  '2.4',
#  '1.8',
#  '17.6',
#  '4240',
#  'Avery Bradley, PG',
#  'bos',
#  '28',
#  '28',
#  '29.9',
#  '12.3',
#  '0.5',
#  '2.1',
#  '2.7',
#  '1.4',
#  '0.89',
#  '0.21',
#  '1.1',
#  '2.1',
#  '1.3',
#  '10.3',
#  '2489663',
#  'Kelly Olynyk, C',
#  'bos',
#  '29',
#  '13',
#  '25.8',
#  '12.1',
#  '1.5',
#  '4.1',
#  '5.6',
#  '2.0',
#  '1.07',
#  '0.79',
#  '1.7',
#  '3.7',
#  '1.2',
#  '17.3',
#  '6631',
#  'Tyler Zeller, C',
#  'bos',
#  '29',
#  '16',
#  '19.2',
#  '9.5',
#  '1.6',
#  '3.7',
#  '5.3',
#  '1.1',
#  '0.28',
#  '0.79',
#  '0.9',
#  '2.6',
#  '1.3',
#  '21.3',
#  '2745',
#  'Brandon Bass, PF',
#  'bos',
#  '29',
#  '0',
#  '18.1',
#  '8.9',
#  '1.1',
#  '2.6',
#  '3.6',
#  '0.8',
#  '0.48',
#  '0.31',
#  '0.8',
#  '1.5',
#  '1.0',
#  '15.8',
#  '4239',
#  'Evan Turner, SG',
#  'bos',
#  '29',
#  '4',
#  '23.6',
#  '8.7',
#  '0.5',
#  '3.3',
#  '3.8',
#  '3.7',
#  '0.93',
#  '0.31',
#  '2.2',
#  '2.1',
#  '1.7',
#  '12.5',
#  '3026',
#  'Rajon Rondo, PG†',
#  'bos',
#  '22',
#  '22',
#  '31.8',
#  '8.3',
#  '1.1',
#  '6.4',
#  '7.5',
#  '10.8',
#  '1.68',
#  '0.14',
#  '3.4',
#  '1.9',
#  '3.2',
#  '15.2',
#  '4017',
#  'Marcus Thornton, SG',
#  'bos',
#  '20',
#  '0',
#  '15.4',
#  '8.2',
#  '0.4',
#  '1.0',
#  '1.4',
#  '0.8',
#  '0.45',
#  '0.25',
#  '0.6',
#  '0.6',
#  '1.4',
#  '15.3',
#  '2990992',
#  'Marcus Smart, PG',
#  'bos',
#  '16',
#  '3',
#  '19.3',
#  '5.8',
#  '0.8',
#  '1.6',
#  '2.4',
#  '2.2',
#  '1.06',
#  '0.13',
#  '1.4',
#  '2.1',
#  '1.5',
#  '9.9',
#  '6581',
#  'Jae Crowder, SF†',
#  'bos',
#  '5',
#  '0',
#  '14.6',
#  '5.4',
#  '1.0',
#  '1.2',
#  '2.2',
#  '0.4',
#  '0.60',
#  '0.20',
#  '0.2',
#  '1.0',
#  '2.0',
#  '13.6',
#  '3242',
#  'Brandan Wright, PF†',
#  'bos',
#  '5',
#  '0',
#  '10.2',
#  '4.6',
#  '0.6',
#  '1.4',
#  '2.0',
#  '0.4',
#  '0.20',
#  '0.40',
#  '0.8',
#  '0.6',
#  '0.5',
#  '15.6',
#  '2439',
#  'Jameer Nelson, PG†',
#  'bos',
#  '5',
#  '1',
#  '21.4',
#  '4.4',
#  '0.6',
#  '2.0',
#  '2.6',
#  '6.6',
#  '1.40',
#  '0.00',
#  '1.6',
#  '2.4',
#  '4.1',
#  '9.9',
#  '2530722',
#  'Phil Pressey, PG',
#  'bos',
#  '19',
#  '0',
#  '12.7',
#  '2.7',
#  '0.3',
#  '1.3',
#  '1.5',
#  '2.3',
#  '0.79',
#  '0.05',
#  '0.8',
#  '1.2',
#  '2.9',
#  '9.0',
#  '3064509',
#  'James Young, SG',
#  'bos',
#  '5',
#  '0',
#  '3.6',
#  '2.2',
#  '0.0',
#  '0.4',
#  '0.4',
#  '0.2',
#  '0.00',
#  '0.20',
#  '0.0',
#  '0.2',
#  '0.0',
#  '22.4',
#  '2531367',
#  'Dwight Powell, PF†',
#  'bos',
#  '5',
#  '0',
#  '1.8',
#  '1.8',
#  '0.0',
#  '0.2',
#  '0.2',
#  '0.0',
#  '0.40',
#  '0.00',
#  '0.4',
#  '0.2',
#  '0.0',
#  '34.2',
#  '1026',
#  'Gerald Wallace, SF',
#  'bos',
#  '13',
#  '0',
#  '7.3',
#  '0.5',
#  '0.2',
#  '0.5',
#  '0.8',
#  '0.2',
#  '0.54',
#  '0.15',
#  '0.4',
#  '0.7',
#  '0.4',
#  '4.1',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  'bos',
#  ...]

# %%
index = 2
increment = 0
for player in players:
    players.insert(index + increment, team_code)
    index = index + 16
    increment = increment + 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e9ab434b73db> in <module>()
#       3 for player in players:
#       4     players.insert(index + increment, team_code)
# ----> 5     index = index + 16
#       6     increment = increment + 1
#
# KeyboardInterrupt:

# %%
# http://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks-in-python
def chunks(l, n):
    """ Yield successive n-sized chunks from l.
    """
    for i in range(0, len(l), n):
        yield l[i:i+n]

# %%
import sqlite3
conn = sqlite3.connect('/home/pybokeh/databases/nba')
c = conn.cursor()

try:
    for player in chunks(players, 16):
        c.execute('INSERT INTO player_game_statistics VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)', player)
        conn.commit()
except:
    pass
    
conn.close()

# %%
def chunks(l, n):
    """ Yield successive n-sized chunks from l.
    """
    for i in range(0, len(l), n):
        yield l[i:i+n]

# %%
from pprint import pprint

for item in chunks(players, 16):
    pprint(item)
# Out:
# ['3209',
#  'Jeff Green, SF',
#  '29',
#  '29',
#  '33.3',
#  '18.5',
#  '0.7',
#  '3.6',
#  '4.2',
#  '1.6',
#  '0.83',
#  '0.41',
#  '1.7',
#  '2.0',
#  '0.9',
#  '15.7']
# ['6624',
#  'Jared Sullinger, PF',
#  '29',
#  '29',
#  '27.9',
#  '13.5',
#  '2.3',
#  '5.6',
#  '7.9',
#  '2.3',
#  '0.59',
#  '0.72',
#  '1.2',
#  '2.4',
#  '1.8',
#  '17.6']
# ['4240',
#  'Avery Bradley, PG',
#  '28',
#  '28',
#  '29.9',
#  '12.3',
#  '0.5',
#  '2.1',
#  '2.7',
#  '1.4',
#  '0.89',
#  '0.21',
#  '1.1',
#  '2.1',
#  '1.3',
#  '10.3']
# ['2489663',
#  'Kelly Olynyk, C',
#  '29',
#  '13',
#  '25.8',
#  '12.1',
#  '1.5',
#  '4.1',
#  '5.6',
#  '2.0',
#  '1.07',
#  '0.79',
#  '1.7',
#  '3.7',
#  '1.2',
#  '17.3']
# ['6631',
#  'Tyler Zeller, C',
#  '29',
#  '16',
#  '19.2',
#  '9.5',
#  '1.6',
#  '3.7',
#  '5.3',
#  '1.1',
#  '0.28',
#  '0.79',
#  '0.9',
#  '2.6',
#  '1.3',
#  '21.3']
# ['2745',
#  'Brandon Bass, PF',
#  '29',
#  '0',
#  '18.1',
#  '8.9',
#  '1.1',
#  '2.6',
#  '3.6',
#  '0.8',
#  '0.48',
#  '0.31',
#  '0.8',
#  '1.5',
#  '1.0',
#  '15.8']
# ['4239',
#  'Evan Turner, SG',
#  '29',
#  '4',
#  '23.6',
#  '8.7',
#  '0.5',
#  '3.3',
#  '3.8',
#  '3.7',
#  '0.93',
#  '0.31',
#  '2.2',
#  '2.1',
#  '1.7',
#  '12.6']
# ['3026',
#  'Rajon Rondo, PG†',
#  '22',
#  '22',
#  '31.8',
#  '8.3',
#  '1.1',
#  '6.4',
#  '7.5',
#  '10.8',
#  '1.68',
#  '0.14',
#  '3.4',
#  '1.9',
#  '3.2',
#  '15.2']
# ['4017',
#  'Marcus Thornton, SG',
#  '20',
#  '0',
#  '15.4',
#  '8.2',
#  '0.4',
#  '1.0',
#  '1.4',
#  '0.8',
#  '0.45',
#  '0.25',
#  '0.6',
#  '0.6',
#  '1.4',
#  '15.3']
# ['2990992',
#  'Marcus Smart, PG',
#  '16',
#  '3',
#  '19.3',
#  '5.8',
#  '0.8',
#  '1.6',
#  '2.4',
#  '2.2',
#  '1.06',
#  '0.13',
#  '1.4',
#  '2.1',
#  '1.5',
#  '9.9']
# ['6581',
#  'Jae Crowder, SF†',
#  '5',
#  '0',
#  '14.6',
#  '5.4',
#  '1.0',
#  '1.2',
#  '2.2',
#  '0.4',
#  '0.60',
#  '0.20',
#  '0.2',
#  '1.0',
#  '2.0',
#  '13.6']
# ['3242',
#  'Brandan Wright, PF†',
#  '5',
#  '0',
#  '10.2',
#  '4.6',
#  '0.6',
#  '1.4',
#  '2.0',
#  '0.4',
#  '0.20',
#  '0.40',
#  '0.8',
#  '0.6',
#  '0.5',
#  '15.6']
# ['2439',
#  'Jameer Nelson, PG†',
#  '5',
#  '1',
#  '21.4',
#  '4.4',
#  '0.6',
#  '2.0',
#  '2.6',
#  '6.6',
#  '1.40',
#  '0.00',
#  '1.6',
#  '2.4',
#  '4.1',
#  '9.9']
# ['2530722',
#  'Phil Pressey, PG',
#  '19',
#  '0',
#  '12.7',
#  '2.7',
#  '0.3',
#  '1.3',
#  '1.5',
#  '2.3',
#  '0.79',
#  '0.05',
#  '0.8',
#  '1.2',
#  '2.9',
#  '9.0']
# ['3064509',
#  'James Young, SG',
#  '5',
#  '0',
#  '3.6',
#  '2.2',
#  '0.0',
#  '0.4',
#  '0.4',
#  '0.2',
#  '0.00',
#  '0.20',
#  '0.0',
#  '0.2',
#  '0.0',
#  '22.4']
# ['2531367',
#  'Dwight Powell, PF†',
#  '5',
#  '0',
#  '1.8',
#  '1.8',
#  '0.0',
#  '0.2',
#  '0.2',
#  '0.0',
#  '0.40',
#  '0.00',
#  '0.4',
#  '0.2',
#  '0.0',
#  '34.2']
# ['1026',
#  'Gerald Wallace, SF',
#  '13',
#  '0',
#  '7.3',
#  '0.5',
#  '0.2',
#  '0.5',
#  '0.8',
#  '0.2',
#  '0.54',
#  '0.15',
#  '0.4',
#  '0.7',
#  '0.4',
#  '4.1']
